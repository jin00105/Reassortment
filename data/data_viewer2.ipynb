# %% [markdown]
# More refined and easy to use data analyzer for reassortment project. Organized well for meta model, not so much for comp model.

# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt
import analysis as ana
from importlib import reload
reload(ana)
# %matplotlib inline
# parameters
direc = 'test2/temp' # directory within 'data/' where the files that you want plot are in
win = 1 # display winning probability
kmplot = 1 # display kmean vs generation plot: 0=noplot 1=k1&k2, 2=k1, 3=k2
p2print = ['K0'] # type parameter you want to print out in a list
sortpar = ['K0'] # type parameter you want to sort the order of graphs by.
repcap = [1,10]#[1,100] #graph certain range of reps (e.g. [1,100]=graph rep=1 to 1000)
histrep = [2] #rep to plot in histogram
histgen = [10,20,30] #generations to plot in histogram
ana.display(direc,win,kmplot,p2print,sortpar,repcap,histrep,histgen)
# Out:
# parameter information
# file1: ['1', '2', '30', '0.050', '1000', '1000', '0.06000', '10000', '0.0000000', '0.50', '20', '1', '0.10000', '0.01000', '0.00', '0.00', '0.0001000', '1.0']
#
#
# file1: m1.1.3s_1,2,30,0.050,1000,1000,0.06000,10000,0.0000000,0.50,20,1,0.10000,0.01000,0.00,0.00,0.0001000,1.0(2).csv
# description: testy_test
#
# K0=1000
#
#
# gen=10
# seg1 var: 0.804286, mean: 0.794318
# seg2 var: nan, mean: nan
#
#
# gen=20
# seg1 var: 1.241306, mean: 1.209546
# seg2 var: nan, mean: nan
#
#
# gen=30
# seg1 var: 1.954701, mean: 1.807556
# seg2 var: nan, mean: nan
# /home/hyunseok/Desktop/YS/Reassortment/data/analysis.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   p2mean = p2mean/np.sum(pop2)
# reps= 30
